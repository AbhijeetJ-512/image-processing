# %%
import numpy as np
import os
from PIL import Image
from scipy import  misc
import matplotlib.pyplot as plt
import cv2

# %%
x = np.array([[1,2],[3,4]])
print(x)

# %%
print(x.ndim)
print(x.shape)

# %%
mystery_array = np.array([[[0, 1, 2, 3],
                           [4, 5, 6, 7]],

                         [[7, 86, 6, 98],
                          [5, 1, 0, 4]],

                          [[5, 36, 32, 48],
                           [97, 0, 27, 18]]])

# Note all the square brackets!
# write your code here
print(mystery_array.ndim)
print(mystery_array.shape)
print(mystery_array[2,1,3])
print(mystery_array[2,1,:])
print(mystery_array[:,:,0])

# %%
y= np.arange(0,10)
print(y)
print(y.max())
print(y.min())
print(y.mean())

# %%
matrx_2D=np.array([[1,2],[3,4]])
matrx_2D

# %%
matrx_2D = matrx_2D +2
matrx_2D

# %%
tree_img = cv2.imread('images/tree.png')
cv2.imshow('image',tree_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
plt.imshow(tree_img)
plt.axis('off')
plt.show()

# %%
red_image = tree_img
red_image[0,:,:]=0
cv2.imshow('tedt',red_image)
cv2.waitKey(0)
# Out:
# -1

# %%
plt.imshow(255-tree_img)

# %%
tree_img = cv2.imread('images/tree.png')
plt.imshow(tree_img)
plt.axis('off')
plt.show()
print(tree_img.shape)

# %%
tree_img=
print(tree_img)
plt.imshow(tree_img)
