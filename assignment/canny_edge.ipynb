# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
modi_image = cv.imread("images/modi.jpg", 0)
edge_modi[100:500, 450:900] = cv.Canny(modi_image[100:500, 450:900], 100, 100)
plt.imshow(edge_modi[100:500, 450:900])
